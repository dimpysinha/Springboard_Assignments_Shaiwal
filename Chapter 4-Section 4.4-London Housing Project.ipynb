# %%
import pandas as pd # import pandas
import numpy as np # import numpy
import matplotlib.pyplot as plt # import matplotlib

# %%
url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

properties = pd.read_excel(url_LondonHousePrices, sheet_name = 'Average price', index_col = None)

# %%
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          91449            50460.2    93284.5    64958.1
# 2 1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3 1995-03-01        79120.7              51269    92247.5    64367.5
# 4 1995-04-01        77101.2            53133.5    90762.9    64277.7
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
# 1    71306.6    81671.5     120933    69158.2    79885.9  ...    43958.5
# 2    72022.3    81657.6     119509    68951.1    80897.1  ...    43925.4
# 3    72015.8    81449.3     120282    68712.4    81379.9  ...    44434.9
# 4    72965.6    81124.4     120098      68610    82188.9  ...    44267.8
#
#   YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# 0          E12000003     E12000004     E12000005       E12000006  E12000007
# 1            44803.4       45544.5       48527.5         56701.6    74435.8
# 2            44528.8       46051.6       49341.3         56593.6    72777.9
# 3            45200.5       45383.8       49442.2         56171.2    73896.8
# 4            45614.3       46124.2       49455.9         56567.9    74455.3
#
#   SOUTH EAST SOUTH WEST Unnamed: 47    England
# 0  E12000008  E12000009         NaN  E92000001
# 1    64018.9    54705.2         NaN    53202.8
# 2      63715    54356.1         NaN    53096.2
# 3    64113.6    53583.1         NaN    53201.3
# 4    64623.2      54786         NaN    53590.9
#
# [5 rows x 49 columns]

# %%
properties = properties.transpose()
properties.head(5)
# Out:
#                           0                    1                    2    \
# Unnamed: 0                NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London      E09000001                91449              82202.8
# Barking & Dagenham  E09000002              50460.2              51085.8
# Barnet              E09000003              93284.5              93190.2
# Bexley              E09000004              64958.1              64787.9
#
#                                     3                    4    \
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00
# City of London                  79120.7              77101.2
# Barking & Dagenham                51269              53133.5
# Barnet                          92247.5              90762.9
# Bexley                          64367.5              64277.7
#
#                                     5                    6    \
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00
# City of London                  84409.1              94900.5
# Barking & Dagenham              53042.2              53700.3
# Barnet                            90258              90107.2
# Bexley                          63997.1              64252.3
#
#                                     7                    8    \
# Unnamed: 0          1995-07-01 00:00:00  1995-08-01 00:00:00
# City of London                   110128               112329
# Barking & Dagenham              52113.1              52232.2
# Barnet                          91441.2              92361.3
# Bexley                          63722.7              64432.6
#
#                                     9    ...                  294  \
# Unnamed: 0          1995-09-01 00:00:00  ...  2019-06-01 00:00:00
# City of London                   104473  ...               761526
# Barking & Dagenham              51471.6  ...               293889
# Barnet                          93273.1  ...               512694
# Bexley                          64509.5  ...               339324
#
#                                     295                  296  \
# Unnamed: 0          2019-07-01 00:00:00  2019-08-01 00:00:00
# City of London                   756407               813770
# Barking & Dagenham               297426               299421
# Barnet                           514668               528577
# Bexley                           338346               337523
#
#                                     297                  298  \
# Unnamed: 0          2019-09-01 00:00:00  2019-10-01 00:00:00
# City of London                   810455               826227
# Barking & Dagenham               304778               304579
# Barnet                           526670               525678
# Bexley                           333340               332920
#
#                                     299                  300  \
# Unnamed: 0          2019-11-01 00:00:00  2019-12-01 00:00:00
# City of London                   776894               737275
# Barking & Dagenham               306390               301283
# Barnet                           522639               519306
# Bexley                           333657               336302
#
#                                     301                  302  \
# Unnamed: 0          2020-01-01 00:00:00  2020-02-01 00:00:00
# City of London                   757377               765416
# Barking & Dagenham               304187               304719
# Barnet                           520115               520966
# Bexley                           334430               334845
#
#                                     303
# Unnamed: 0          2020-03-01 00:00:00
# City of London                   792583
# Barking & Dagenham               327136
# Barnet                           532569
# Bexley                           331679
#
# [5 rows x 304 columns]

# %%
properties.index
# Out:
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %%
properties = properties.reset_index()
properties.index
# Out:
# RangeIndex(start=0, stop=49, step=1)

# %%
properties.head()
# Out:
#                 index          0                    1                    2  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001                91449              82202.8
# 2  Barking & Dagenham  E09000002              50460.2              51085.8
# 3              Barnet  E09000003              93284.5              93190.2
# 4              Bexley  E09000004              64958.1              64787.9
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1              79120.7              77101.2              84409.1
# 2                51269              53133.5              53042.2
# 3              92247.5              90762.9                90258
# 4              64367.5              64277.7              63997.1
#
#                      6                    7                    8  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
# 1              94900.5               110128               112329  ...
# 2              53700.3              52113.1              52232.2  ...
# 3              90107.2              91441.2              92361.3  ...
# 4              64252.3              63722.7              64432.6  ...
#
#                    294                  295                  296  \
# 0  2019-06-01 00:00:00  2019-07-01 00:00:00  2019-08-01 00:00:00
# 1               761526               756407               813770
# 2               293889               297426               299421
# 3               512694               514668               528577
# 4               339324               338346               337523
#
#                    297                  298                  299  \
# 0  2019-09-01 00:00:00  2019-10-01 00:00:00  2019-11-01 00:00:00
# 1               810455               826227               776894
# 2               304778               304579               306390
# 3               526670               525678               522639
# 4               333340               332920               333657
#
#                    300                  301                  302  \
# 0  2019-12-01 00:00:00  2020-01-01 00:00:00  2020-02-01 00:00:00
# 1               737275               757377               765416
# 2               301283               304187               304719
# 3               519306               520115               520966
# 4               336302               334430               334845
#
#                    303
# 0  2020-03-01 00:00:00
# 1               792583
# 2               327136
# 3               532569
# 4               331679
#
# [5 rows x 305 columns]

# %%
properties.columns
# Out:
# Index(['index',       0,       1,       2,       3,       4,       5,       6,
#              7,       8,
#        ...
#            294,     295,     296,     297,     298,     299,     300,     301,
#            302,     303],
#       dtype='object', length=305)

# %%
properties.columns = properties.iloc[0]
properties.head()
# Out:
# 0          Unnamed: 0        NaN  1995-01-01 00:00:00  1995-02-01 00:00:00  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001                91449              82202.8
# 2  Barking & Dagenham  E09000002              50460.2              51085.8
# 3              Barnet  E09000003              93284.5              93190.2
# 4              Bexley  E09000004              64958.1              64787.9
#
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1              79120.7              77101.2              84409.1
# 2                51269              53133.5              53042.2
# 3              92247.5              90762.9                90258
# 4              64367.5              64277.7              63997.1
#
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
# 1              94900.5               110128               112329  ...
# 2              53700.3              52113.1              52232.2  ...
# 3              90107.2              91441.2              92361.3  ...
# 4              64252.3              63722.7              64432.6  ...
#
# 0  2019-06-01 00:00:00  2019-07-01 00:00:00  2019-08-01 00:00:00  \
# 0  2019-06-01 00:00:00  2019-07-01 00:00:00  2019-08-01 00:00:00
# 1               761526               756407               813770
# 2               293889               297426               299421
# 3               512694               514668               528577
# 4               339324               338346               337523
#
# 0  2019-09-01 00:00:00  2019-10-01 00:00:00  2019-11-01 00:00:00  \
# 0  2019-09-01 00:00:00  2019-10-01 00:00:00  2019-11-01 00:00:00
# 1               810455               826227               776894
# 2               304778               304579               306390
# 3               526670               525678               522639
# 4               333340               332920               333657
#
# 0  2019-12-01 00:00:00  2020-01-01 00:00:00  2020-02-01 00:00:00  \
# 0  2019-12-01 00:00:00  2020-01-01 00:00:00  2020-02-01 00:00:00
# 1               737275               757377               765416
# 2               301283               304187               304719
# 3               519306               520115               520966
# 4               336302               334430               334845
#
# 0  2020-03-01 00:00:00
# 0  2020-03-01 00:00:00
# 1               792583
# 2               327136
# 3               532569
# 4               331679
#
# [5 rows x 305 columns]

# %%
properties.drop(0)
# Out:
# 0             Unnamed: 0        NaN 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1         City of London  E09000001               91449             82202.8
# 2     Barking & Dagenham  E09000002             50460.2             51085.8
# 3                 Barnet  E09000003             93284.5             93190.2
# 4                 Bexley  E09000004             64958.1             64787.9
# 5                  Brent  E09000005             71306.6             72022.3
# 6                Bromley  E09000006             81671.5             81657.6
# 7                 Camden  E09000007              120933              119509
# 8                Croydon  E09000008             69158.2             68951.1
# 9                 Ealing  E09000009             79885.9             80897.1
# 10               Enfield  E09000010             72514.7             73155.2
# 11             Greenwich  E09000011             62300.1             60993.3
# 12               Hackney  E09000012             61296.5             63187.1
# 13  Hammersmith & Fulham  E09000013              124903              122088
# 14              Haringey  E09000014             76287.6             78901.2
# 15                Harrow  E09000015             84769.5             83396.1
# 16              Havering  E09000016             68000.1             69393.5
# 17            Hillingdon  E09000017             73834.8             75031.1
# 18              Hounslow  E09000018             72231.7             71051.6
# 19             Islington  E09000019             92516.5             94342.4
# 20  Kensington & Chelsea  E09000020              182695              182345
# 21  Kingston upon Thames  E09000021             80875.8             81230.1
# 22               Lambeth  E09000022               67771             65381.5
# 23              Lewisham  E09000023             60491.3             60869.3
# 24                Merton  E09000024             82070.6             79982.7
# 25                Newham  E09000025             53539.3             53153.9
# 26             Redbridge  E09000026             72189.6             72141.6
# 27  Richmond upon Thames  E09000027              109326              111103
# 28             Southwark  E09000028             67885.2             64799.1
# 29                Sutton  E09000029               71537             70893.2
# 30         Tower Hamlets  E09000030             59865.2             62318.5
# 31        Waltham Forest  E09000031             61319.4             60252.1
# 32            Wandsworth  E09000032               88559               88641
# 33           Westminster  E09000033              133025              131468
# 34           Unnamed: 34        NaN                 NaN                 NaN
# 35          Inner London  E13000001               78252             75885.7
# 36          Outer London  E13000002             72958.8             72937.9
# 37           Unnamed: 37        NaN                 NaN                 NaN
# 38            NORTH EAST  E12000001             42076.4               42572
# 39            NORTH WEST  E12000002             43958.5             43925.4
# 40    YORKS & THE HUMBER  E12000003             44803.4             44528.8
# 41         EAST MIDLANDS  E12000004             45544.5             46051.6
# 42         WEST MIDLANDS  E12000005             48527.5             49341.3
# 43       EAST OF ENGLAND  E12000006             56701.6             56593.6
# 44                LONDON  E12000007             74435.8             72777.9
# 45            SOUTH EAST  E12000008             64018.9               63715
# 46            SOUTH WEST  E12000009             54705.2             54356.1
# 47           Unnamed: 47        NaN                 NaN                 NaN
# 48               England  E92000001             53202.8             53096.2
#
# 0  1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1              79120.7             77101.2             84409.1
# 2                51269             53133.5             53042.2
# 3              92247.5             90762.9               90258
# 4              64367.5             64277.7             63997.1
# 5              72015.8             72965.6               73704
# 6              81449.3             81124.4             81542.6
# 7               120282              120098              119929
# 8              68712.4               68610             68844.9
# 9              81379.9             82188.9             82077.1
# 10             72190.4             71442.9             70630.8
# 11             61377.8             61927.7               63513
# 12             63593.3             65139.6               66194
# 13              120636              121425              124434
# 14             78521.9             79545.6               79374
# 15             83416.2             83567.9             83853.7
# 16               69368             69444.3             68534.5
# 17             74188.7             73911.4             73117.1
# 18               72098             71890.3             72877.5
# 19             93465.9             93344.5             94346.4
# 20              182879              184177              191474
# 21             81111.5             81672.8             82123.5
# 22             66336.5             66388.8             69035.1
# 23               60288               59471             58551.4
# 24             80661.7             79990.5               80874
# 25             53458.3             54479.8               55804
# 26             72501.4             72228.6             72366.6
# 27              107325              106875              107708
# 28             65763.3             63073.6             64420.5
# 29             70306.8             69411.9             69759.2
# 30             63938.7             66233.2             66432.9
# 31             60871.1             60971.4             61494.2
# 32             87124.8               87026             86518.1
# 33              132260              133370              133911
# 34                 NaN                 NaN                 NaN
# 35             76591.6             76851.6             79129.2
# 36             72714.5             72591.9               72753
# 37                 NaN                 NaN                 NaN
# 38             42369.7             42095.8             43266.5
# 39             44434.9             44267.8             44223.6
# 40             45200.5             45614.3               44831
# 41             45383.8             46124.2               45878
# 42             49442.2             49455.9             50369.7
# 43             56171.2             56567.9             56479.8
# 44             73896.8             74455.3               75432
# 45             64113.6             64623.2             64530.4
# 46             53583.1               54786             54698.8
# 47                 NaN                 NaN                 NaN
# 48             53201.3             53590.9             53678.2
#
# 0  1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1              94900.5              110128              112329  ...
# 2              53700.3             52113.1             52232.2  ...
# 3              90107.2             91441.2             92361.3  ...
# 4              64252.3             63722.7             64432.6  ...
# 5              74310.5               74127               73547  ...
# 6              82382.8             82898.5             82054.4  ...
# 7               121887              124028              125530  ...
# 8              69052.5             69142.5             68993.4  ...
# 9              81630.7             82352.2             82706.7  ...
# 10             71348.3             71837.5             72237.9  ...
# 11             64751.6             65486.3             65076.4  ...
# 12             66921.2             68390.8             68096.8  ...
# 13              126175              124382              123625  ...
# 14             79956.4             80746.3             81217.7  ...
# 15             84173.2             84226.7             84430.6  ...
# 16             68464.6             68680.8             69023.4  ...
# 17               74005             74671.1             74967.9  ...
# 18             72331.1             73717.8             74479.9  ...
# 19             97428.9             98976.1             98951.2  ...
# 20              197266              197963              198037  ...
# 21             82205.7             82525.8             83342.8  ...
# 22             68881.2             69608.7               68840  ...
# 23             58041.4             58126.4             58151.3  ...
# 24             80704.9             81055.9             80781.1  ...
# 25             56067.8             55458.3             54709.4  ...
# 26             72279.4             72880.8             73275.2  ...
# 27              112865              114657              112320  ...
# 28             64155.8             67024.7             65525.9  ...
# 29             70125.2             70789.6             69958.4  ...
# 30             66232.2             64692.2             63472.3  ...
# 31             61547.8             61933.5             61916.4  ...
# 32             88114.3             89830.6             90560.7  ...
# 33              134562              133450              136582  ...
# 34                 NaN                 NaN                 NaN  ...
# 35             79969.2             80550.5             80597.6  ...
# 36             73189.4             73665.9             73691.1  ...
# 37                 NaN                 NaN                 NaN  ...
# 38             42315.3             43287.7             41899.1  ...
# 39               44113             44109.6             44193.7  ...
# 40             45392.6               45535             45111.5  ...
# 41               45680             46037.7             45922.5  ...
# 42             50100.4               49860             49598.5  ...
# 43             56288.9             57242.3             56732.4  ...
# 44             75606.2             75984.2             75529.3  ...
# 45               65511             65224.9             64851.6  ...
# 46             54420.2             54265.9             54365.7  ...
# 47                 NaN                 NaN                 NaN  ...
# 48             53735.2             53900.6             53600.3  ...
#
# 0  2019-06-01 00:00:00 2019-07-01 00:00:00 2019-08-01 00:00:00  \
# 1               761526              756407              813770
# 2               293889              297426              299421
# 3               512694              514668              528577
# 4               339324              338346              337523
# 5               474821              473849              488784
# 6               430002              434257              442189
# 7               871957              890288              863171
# 8               363420              365875              364540
# 9               474844              475592              474627
# 10              390708              388053              393033
# 11              388252              397828              396858
# 12              546344              555779              567269
# 13              713137              725253              729659
# 14              540626              550393              544194
# 15              447719              446095              450373
# 16              365336              367679              367502
# 17              395982              398547              397385
# 18              399687              397246              401911
# 19              625315              629281              643335
# 20         1.29176e+06         1.27544e+06         1.24853e+06
# 21              484676              502895              508405
# 22              503721              510045              519956
# 23              405009              410983              416885
# 24              498683              504702              517489
# 25              359953              359106              361920
# 26              408514              414968              421319
# 27              652859              657619              657974
# 28              494784              499663              496718
# 29              371680              373534              368908
# 30              428705              431290              441364
# 31              421958              418743              427416
# 32              574833              585174              592251
# 33              995108              948507              905951
# 34                 NaN                 NaN                 NaN
# 35              565090              569219              571439
# 36              419287              421920              425263
# 37                 NaN                 NaN                 NaN
# 38              129488              129756              131515
# 39              163927              166137              167490
# 40              163781              165119              165441
# 41              192144              193549              195268
# 42              196666              197938              200858
# 43              288717              291700              290623
# 44              470878              478858              472872
# 45              321041              322863              323122
# 46              252946              258449              258241
# 47                 NaN                 NaN                 NaN
# 48              246014              248652              249294
#
# 0  2019-09-01 00:00:00 2019-10-01 00:00:00 2019-11-01 00:00:00  \
# 1               810455              826227              776894
# 2               304778              304579              306390
# 3               526670              525678              522639
# 4               333340              332920              333657
# 5               501533              494770              432188
# 6               441058              439178              436080
# 7               838170              804713              825336
# 8               365226              364413              367585
# 9               473162              477369              475492
# 10              386806              392721              393255
# 11              403730              401559              405337
# 12              573270              566979              559758
# 13              735538              719932              719751
# 14              553640              554123              559426
# 15              453155              453783              450109
# 16              366447              367102              365861
# 17              403945              403300              407706
# 18              406930              413132              410071
# 19              655061              645212              630659
# 20         1.23018e+06         1.19044e+06         1.19405e+06
# 21              504867              488211              490420
# 22              520403              515947              519410
# 23              420341              421258              415893
# 24              515391              509006              501570
# 25              368687              369972              363114
# 26              414268              411874              413882
# 27              648147              643769              650949
# 28              507466              513615              510619
# 29              372899              369917              374775
# 30              447629              452040              450989
# 31              432270              434921              435568
# 32              605559              600642              601650
# 33              922687              927735              955265
# 34                 NaN                 NaN                 NaN
# 35              577554              574464              573932
# 36              425804              424942              423311
# 37                 NaN                 NaN                 NaN
# 38              131952              129462              129658
# 39              166796              166640              165808
# 40              165407              166494              164499
# 41              194808              194674              194855
# 42              200969              200116              200896
# 43              291944              291196              288781
# 44              477779              474156              468983
# 45              324357              323278              322512
# 46              258751              258880              256875
# 47                 NaN                 NaN                 NaN
# 48              249771              249152              247951
#
# 0  2019-12-01 00:00:00 2020-01-01 00:00:00 2020-02-01 00:00:00  \
# 1               737275              757377              765416
# 2               301283              304187              304719
# 3               519306              520115              520966
# 4               336302              334430              334845
# 5               427126              424663              471574
# 6               438682              435337              436544
# 7               807124              816906              818558
# 8               369568              371918              371686
# 9               469662              467351              467963
# 10              400182              390575              391100
# 11              398024              396726              399806
# 12              552785              560644              575907
# 13              728698              742390              754150
# 14              565582              561555              551360
# 15              446900              447786              457364
# 16              365886              361905              362665
# 17              404843              407688              404694
# 18              409569              410271              408460
# 19              648969              671871              674948
# 20         1.23176e+06         1.24502e+06         1.30433e+06
# 21              487696              489615              487604
# 22              521705              527597              529832
# 23              413462              409272              413063
# 24              500651              503834              502533
# 25              360934              368245              377365
# 26              424631              423587              424049
# 27              655378              665797              661396
# 28              505499              500395              504045
# 29              372581              372145              373843
# 30              456436              464737              473410
# 31              437333              442368              441461
# 32              605560              606271              605237
# 33              960943         1.00128e+06         1.04288e+06
# 34                 NaN                 NaN                 NaN
# 35              575132              580890              587586
# 36              423156              422977              425243
# 37                 NaN                 NaN                 NaN
# 38              129504              128425              127741
# 39              164893              165024              165917
# 40              165818              164838              165232
# 41              194553              196277              193858
# 42              198644              202289              200577
# 43              290814              290548              291261
# 44              478576              479166              479974
# 45              321972              323967              321268
# 46              256577              258185              258129
# 47                 NaN                 NaN                 NaN
# 48              248250              249160              248587
#
# 0  2020-03-01 00:00:00
# 1               792583
# 2               327136
# 3               532569
# 4               331679
# 5               446966
# 6               430033
# 7               881096
# 8               358356
# 9               454027
# 10              386000
# 11              415693
# 12              638683
# 13              747174
# 14              565343
# 15              454716
# 16              352951
# 17              417977
# 18              423042
# 19              632270
# 20          1.3961e+06
# 21              506000
# 22              525487
# 23              424233
# 24              509252
# 25              387326
# 26              418473
# 27              633481
# 28              488610
# 29              377458
# 30              472662
# 31              437153
# 32              624858
# 33         1.08501e+06
# 34                 NaN
# 35              597617
# 36              424295
# 37                 NaN
# 38              126945
# 39              166202
# 40              159208
# 41              194664
# 42              195917
# 43              291254
# 44              485794
# 45              323353
# 46              263360
# 47                 NaN
# 48              248271
#
# [48 rows x 305 columns]

# %%
properties = properties.rename(columns = {'Unnamed: 0' : 'BOROUGHS_LONDON', pd.NaT : 'CITY_ID'})
properties.drop(0)
# Out:
# 0        BOROUGHS_LONDON    CITY_ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1         City of London  E09000001               91449             82202.8
# 2     Barking & Dagenham  E09000002             50460.2             51085.8
# 3                 Barnet  E09000003             93284.5             93190.2
# 4                 Bexley  E09000004             64958.1             64787.9
# 5                  Brent  E09000005             71306.6             72022.3
# 6                Bromley  E09000006             81671.5             81657.6
# 7                 Camden  E09000007              120933              119509
# 8                Croydon  E09000008             69158.2             68951.1
# 9                 Ealing  E09000009             79885.9             80897.1
# 10               Enfield  E09000010             72514.7             73155.2
# 11             Greenwich  E09000011             62300.1             60993.3
# 12               Hackney  E09000012             61296.5             63187.1
# 13  Hammersmith & Fulham  E09000013              124903              122088
# 14              Haringey  E09000014             76287.6             78901.2
# 15                Harrow  E09000015             84769.5             83396.1
# 16              Havering  E09000016             68000.1             69393.5
# 17            Hillingdon  E09000017             73834.8             75031.1
# 18              Hounslow  E09000018             72231.7             71051.6
# 19             Islington  E09000019             92516.5             94342.4
# 20  Kensington & Chelsea  E09000020              182695              182345
# 21  Kingston upon Thames  E09000021             80875.8             81230.1
# 22               Lambeth  E09000022               67771             65381.5
# 23              Lewisham  E09000023             60491.3             60869.3
# 24                Merton  E09000024             82070.6             79982.7
# 25                Newham  E09000025             53539.3             53153.9
# 26             Redbridge  E09000026             72189.6             72141.6
# 27  Richmond upon Thames  E09000027              109326              111103
# 28             Southwark  E09000028             67885.2             64799.1
# 29                Sutton  E09000029               71537             70893.2
# 30         Tower Hamlets  E09000030             59865.2             62318.5
# 31        Waltham Forest  E09000031             61319.4             60252.1
# 32            Wandsworth  E09000032               88559               88641
# 33           Westminster  E09000033              133025              131468
# 34           Unnamed: 34        NaN                 NaN                 NaN
# 35          Inner London  E13000001               78252             75885.7
# 36          Outer London  E13000002             72958.8             72937.9
# 37           Unnamed: 37        NaN                 NaN                 NaN
# 38            NORTH EAST  E12000001             42076.4               42572
# 39            NORTH WEST  E12000002             43958.5             43925.4
# 40    YORKS & THE HUMBER  E12000003             44803.4             44528.8
# 41         EAST MIDLANDS  E12000004             45544.5             46051.6
# 42         WEST MIDLANDS  E12000005             48527.5             49341.3
# 43       EAST OF ENGLAND  E12000006             56701.6             56593.6
# 44                LONDON  E12000007             74435.8             72777.9
# 45            SOUTH EAST  E12000008             64018.9               63715
# 46            SOUTH WEST  E12000009             54705.2             54356.1
# 47           Unnamed: 47        NaN                 NaN                 NaN
# 48               England  E92000001             53202.8             53096.2
#
# 0  1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1              79120.7             77101.2             84409.1
# 2                51269             53133.5             53042.2
# 3              92247.5             90762.9               90258
# 4              64367.5             64277.7             63997.1
# 5              72015.8             72965.6               73704
# 6              81449.3             81124.4             81542.6
# 7               120282              120098              119929
# 8              68712.4               68610             68844.9
# 9              81379.9             82188.9             82077.1
# 10             72190.4             71442.9             70630.8
# 11             61377.8             61927.7               63513
# 12             63593.3             65139.6               66194
# 13              120636              121425              124434
# 14             78521.9             79545.6               79374
# 15             83416.2             83567.9             83853.7
# 16               69368             69444.3             68534.5
# 17             74188.7             73911.4             73117.1
# 18               72098             71890.3             72877.5
# 19             93465.9             93344.5             94346.4
# 20              182879              184177              191474
# 21             81111.5             81672.8             82123.5
# 22             66336.5             66388.8             69035.1
# 23               60288               59471             58551.4
# 24             80661.7             79990.5               80874
# 25             53458.3             54479.8               55804
# 26             72501.4             72228.6             72366.6
# 27              107325              106875              107708
# 28             65763.3             63073.6             64420.5
# 29             70306.8             69411.9             69759.2
# 30             63938.7             66233.2             66432.9
# 31             60871.1             60971.4             61494.2
# 32             87124.8               87026             86518.1
# 33              132260              133370              133911
# 34                 NaN                 NaN                 NaN
# 35             76591.6             76851.6             79129.2
# 36             72714.5             72591.9               72753
# 37                 NaN                 NaN                 NaN
# 38             42369.7             42095.8             43266.5
# 39             44434.9             44267.8             44223.6
# 40             45200.5             45614.3               44831
# 41             45383.8             46124.2               45878
# 42             49442.2             49455.9             50369.7
# 43             56171.2             56567.9             56479.8
# 44             73896.8             74455.3               75432
# 45             64113.6             64623.2             64530.4
# 46             53583.1               54786             54698.8
# 47                 NaN                 NaN                 NaN
# 48             53201.3             53590.9             53678.2
#
# 0  1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1              94900.5              110128              112329  ...
# 2              53700.3             52113.1             52232.2  ...
# 3              90107.2             91441.2             92361.3  ...
# 4              64252.3             63722.7             64432.6  ...
# 5              74310.5               74127               73547  ...
# 6              82382.8             82898.5             82054.4  ...
# 7               121887              124028              125530  ...
# 8              69052.5             69142.5             68993.4  ...
# 9              81630.7             82352.2             82706.7  ...
# 10             71348.3             71837.5             72237.9  ...
# 11             64751.6             65486.3             65076.4  ...
# 12             66921.2             68390.8             68096.8  ...
# 13              126175              124382              123625  ...
# 14             79956.4             80746.3             81217.7  ...
# 15             84173.2             84226.7             84430.6  ...
# 16             68464.6             68680.8             69023.4  ...
# 17               74005             74671.1             74967.9  ...
# 18             72331.1             73717.8             74479.9  ...
# 19             97428.9             98976.1             98951.2  ...
# 20              197266              197963              198037  ...
# 21             82205.7             82525.8             83342.8  ...
# 22             68881.2             69608.7               68840  ...
# 23             58041.4             58126.4             58151.3  ...
# 24             80704.9             81055.9             80781.1  ...
# 25             56067.8             55458.3             54709.4  ...
# 26             72279.4             72880.8             73275.2  ...
# 27              112865              114657              112320  ...
# 28             64155.8             67024.7             65525.9  ...
# 29             70125.2             70789.6             69958.4  ...
# 30             66232.2             64692.2             63472.3  ...
# 31             61547.8             61933.5             61916.4  ...
# 32             88114.3             89830.6             90560.7  ...
# 33              134562              133450              136582  ...
# 34                 NaN                 NaN                 NaN  ...
# 35             79969.2             80550.5             80597.6  ...
# 36             73189.4             73665.9             73691.1  ...
# 37                 NaN                 NaN                 NaN  ...
# 38             42315.3             43287.7             41899.1  ...
# 39               44113             44109.6             44193.7  ...
# 40             45392.6               45535             45111.5  ...
# 41               45680             46037.7             45922.5  ...
# 42             50100.4               49860             49598.5  ...
# 43             56288.9             57242.3             56732.4  ...
# 44             75606.2             75984.2             75529.3  ...
# 45               65511             65224.9             64851.6  ...
# 46             54420.2             54265.9             54365.7  ...
# 47                 NaN                 NaN                 NaN  ...
# 48             53735.2             53900.6             53600.3  ...
#
# 0  2019-06-01 00:00:00 2019-07-01 00:00:00 2019-08-01 00:00:00  \
# 1               761526              756407              813770
# 2               293889              297426              299421
# 3               512694              514668              528577
# 4               339324              338346              337523
# 5               474821              473849              488784
# 6               430002              434257              442189
# 7               871957              890288              863171
# 8               363420              365875              364540
# 9               474844              475592              474627
# 10              390708              388053              393033
# 11              388252              397828              396858
# 12              546344              555779              567269
# 13              713137              725253              729659
# 14              540626              550393              544194
# 15              447719              446095              450373
# 16              365336              367679              367502
# 17              395982              398547              397385
# 18              399687              397246              401911
# 19              625315              629281              643335
# 20         1.29176e+06         1.27544e+06         1.24853e+06
# 21              484676              502895              508405
# 22              503721              510045              519956
# 23              405009              410983              416885
# 24              498683              504702              517489
# 25              359953              359106              361920
# 26              408514              414968              421319
# 27              652859              657619              657974
# 28              494784              499663              496718
# 29              371680              373534              368908
# 30              428705              431290              441364
# 31              421958              418743              427416
# 32              574833              585174              592251
# 33              995108              948507              905951
# 34                 NaN                 NaN                 NaN
# 35              565090              569219              571439
# 36              419287              421920              425263
# 37                 NaN                 NaN                 NaN
# 38              129488              129756              131515
# 39              163927              166137              167490
# 40              163781              165119              165441
# 41              192144              193549              195268
# 42              196666              197938              200858
# 43              288717              291700              290623
# 44              470878              478858              472872
# 45              321041              322863              323122
# 46              252946              258449              258241
# 47                 NaN                 NaN                 NaN
# 48              246014              248652              249294
#
# 0  2019-09-01 00:00:00 2019-10-01 00:00:00 2019-11-01 00:00:00  \
# 1               810455              826227              776894
# 2               304778              304579              306390
# 3               526670              525678              522639
# 4               333340              332920              333657
# 5               501533              494770              432188
# 6               441058              439178              436080
# 7               838170              804713              825336
# 8               365226              364413              367585
# 9               473162              477369              475492
# 10              386806              392721              393255
# 11              403730              401559              405337
# 12              573270              566979              559758
# 13              735538              719932              719751
# 14              553640              554123              559426
# 15              453155              453783              450109
# 16              366447              367102              365861
# 17              403945              403300              407706
# 18              406930              413132              410071
# 19              655061              645212              630659
# 20         1.23018e+06         1.19044e+06         1.19405e+06
# 21              504867              488211              490420
# 22              520403              515947              519410
# 23              420341              421258              415893
# 24              515391              509006              501570
# 25              368687              369972              363114
# 26              414268              411874              413882
# 27              648147              643769              650949
# 28              507466              513615              510619
# 29              372899              369917              374775
# 30              447629              452040              450989
# 31              432270              434921              435568
# 32              605559              600642              601650
# 33              922687              927735              955265
# 34                 NaN                 NaN                 NaN
# 35              577554              574464              573932
# 36              425804              424942              423311
# 37                 NaN                 NaN                 NaN
# 38              131952              129462              129658
# 39              166796              166640              165808
# 40              165407              166494              164499
# 41              194808              194674              194855
# 42              200969              200116              200896
# 43              291944              291196              288781
# 44              477779              474156              468983
# 45              324357              323278              322512
# 46              258751              258880              256875
# 47                 NaN                 NaN                 NaN
# 48              249771              249152              247951
#
# 0  2019-12-01 00:00:00 2020-01-01 00:00:00 2020-02-01 00:00:00  \
# 1               737275              757377              765416
# 2               301283              304187              304719
# 3               519306              520115              520966
# 4               336302              334430              334845
# 5               427126              424663              471574
# 6               438682              435337              436544
# 7               807124              816906              818558
# 8               369568              371918              371686
# 9               469662              467351              467963
# 10              400182              390575              391100
# 11              398024              396726              399806
# 12              552785              560644              575907
# 13              728698              742390              754150
# 14              565582              561555              551360
# 15              446900              447786              457364
# 16              365886              361905              362665
# 17              404843              407688              404694
# 18              409569              410271              408460
# 19              648969              671871              674948
# 20         1.23176e+06         1.24502e+06         1.30433e+06
# 21              487696              489615              487604
# 22              521705              527597              529832
# 23              413462              409272              413063
# 24              500651              503834              502533
# 25              360934              368245              377365
# 26              424631              423587              424049
# 27              655378              665797              661396
# 28              505499              500395              504045
# 29              372581              372145              373843
# 30              456436              464737              473410
# 31              437333              442368              441461
# 32              605560              606271              605237
# 33              960943         1.00128e+06         1.04288e+06
# 34                 NaN                 NaN                 NaN
# 35              575132              580890              587586
# 36              423156              422977              425243
# 37                 NaN                 NaN                 NaN
# 38              129504              128425              127741
# 39              164893              165024              165917
# 40              165818              164838              165232
# 41              194553              196277              193858
# 42              198644              202289              200577
# 43              290814              290548              291261
# 44              478576              479166              479974
# 45              321972              323967              321268
# 46              256577              258185              258129
# 47                 NaN                 NaN                 NaN
# 48              248250              249160              248587
#
# 0  2020-03-01 00:00:00
# 1               792583
# 2               327136
# 3               532569
# 4               331679
# 5               446966
# 6               430033
# 7               881096
# 8               358356
# 9               454027
# 10              386000
# 11              415693
# 12              638683
# 13              747174
# 14              565343
# 15              454716
# 16              352951
# 17              417977
# 18              423042
# 19              632270
# 20          1.3961e+06
# 21              506000
# 22              525487
# 23              424233
# 24              509252
# 25              387326
# 26              418473
# 27              633481
# 28              488610
# 29              377458
# 30              472662
# 31              437153
# 32              624858
# 33         1.08501e+06
# 34                 NaN
# 35              597617
# 36              424295
# 37                 NaN
# 38              126945
# 39              166202
# 40              159208
# 41              194664
# 42              195917
# 43              291254
# 44              485794
# 45              323353
# 46              263360
# 47                 NaN
# 48              248271
#
# [48 rows x 305 columns]

# %%
properties_1 = pd.melt(properties, id_vars = ['BOROUGHS_LONDON','CITY_ID'])
properties_1.head()
# Out:
#       BOROUGHS_LONDON    CITY_ID          0                value
# 0          Unnamed: 0        NaT 1995-01-01  1995-01-01 00:00:00
# 1      City of London  E09000001 1995-01-01                91449
# 2  Barking & Dagenham  E09000002 1995-01-01              50460.2
# 3              Barnet  E09000003 1995-01-01              93284.5
# 4              Bexley  E09000004 1995-01-01              64958.1

# %%
properties_1.drop(0)
# Out:
#           BOROUGHS_LONDON    CITY_ID          0    value
# 1          City of London  E09000001 1995-01-01    91449
# 2      Barking & Dagenham  E09000002 1995-01-01  50460.2
# 3                  Barnet  E09000003 1995-01-01  93284.5
# 4                  Bexley  E09000004 1995-01-01  64958.1
# 5                   Brent  E09000005 1995-01-01  71306.6
# ...                   ...        ...        ...      ...
# 14842              LONDON  E12000007 2020-03-01   485794
# 14843          SOUTH EAST  E12000008 2020-03-01   323353
# 14844          SOUTH WEST  E12000009 2020-03-01   263360
# 14845         Unnamed: 47        NaN 2020-03-01      NaN
# 14846             England  E92000001 2020-03-01   248271
#
# [14846 rows x 4 columns]

# %%
properties_1 = properties_1.rename(columns = {0 : 'Month', 'value' : 'Average Price'})
properties_1.head()
# Out:
#       BOROUGHS_LONDON    CITY_ID      Month        Average Price
# 0          Unnamed: 0        NaT 1995-01-01  1995-01-01 00:00:00
# 1      City of London  E09000001 1995-01-01                91449
# 2  Barking & Dagenham  E09000002 1995-01-01              50460.2
# 3              Barnet  E09000003 1995-01-01              93284.5
# 4              Bexley  E09000004 1995-01-01              64958.1

# %%
properties_1.drop(0)
# Out:
#           BOROUGHS_LONDON    CITY_ID      Month Average Price
# 1          City of London  E09000001 1995-01-01         91449
# 2      Barking & Dagenham  E09000002 1995-01-01       50460.2
# 3                  Barnet  E09000003 1995-01-01       93284.5
# 4                  Bexley  E09000004 1995-01-01       64958.1
# 5                   Brent  E09000005 1995-01-01       71306.6
# ...                   ...        ...        ...           ...
# 14842              LONDON  E12000007 2020-03-01        485794
# 14843          SOUTH EAST  E12000008 2020-03-01        323353
# 14844          SOUTH WEST  E12000009 2020-03-01        263360
# 14845         Unnamed: 47        NaN 2020-03-01           NaN
# 14846             England  E92000001 2020-03-01        248271
#
# [14846 rows x 4 columns]

# %%
properties_1.shape
# Out:
# (14847, 4)

# %%
properties_1.describe()
# Out:
#        BOROUGHS_LONDON    CITY_ID                Month  Average Price
# count            14847      13635                14847     13938.0000
# unique              49         45                  303     13938.0000
# top       Inner London  E09000024  1997-11-01 00:00:00    196606.0704
# freq               303        303                   49         1.0000
# first              NaN        NaN  1995-01-01 00:00:00            NaN
# last               NaN        NaN  2020-03-01 00:00:00            NaN

# %%
properties_1 = properties_1.dropna(how='any',axis=0)
properties_1.describe()
# Out:
#        BOROUGHS_LONDON    CITY_ID                Month  Average Price
# count            13635      13635                13635    13635.00000
# unique              45         45                  303    13635.00000
# top       Inner London  E09000024  1997-11-01 00:00:00    98302.97736
# freq               303        303                   45        1.00000
# first              NaN        NaN  1995-01-01 00:00:00            NaN
# last               NaN        NaN  2020-03-01 00:00:00            NaN

# %%
properties_1.dtypes
# Out:
# BOROUGHS_LONDON            object
# CITY_ID                    object
# Month              datetime64[ns]
# Average Price              object
# dtype: object

# %%
properties_1['Average Price'] = pd.to_numeric(properties_1['Average Price'])
properties_1.dtypes
# Out:
# BOROUGHS_LONDON            object
# CITY_ID                    object
# Month              datetime64[ns]
# Average Price             float64
# dtype: object

# %%
properties_1.count()
# Out:
# BOROUGHS_LONDON    13635
# CITY_ID            13635
# Month              13635
# Average Price      13635
# dtype: int64

# %%
properties_1.shape
# Out:
# (13635, 4)

# %%
properties_1.head()
# Out:
#       BOROUGHS_LONDON    CITY_ID      Month  Average Price
# 1      City of London  E09000001 1995-01-01    91448.98487
# 2  Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 3              Barnet  E09000003 1995-01-01    93284.51832
# 4              Bexley  E09000004 1995-01-01    64958.09036
# 5               Brent  E09000005 1995-01-01    71306.56698

# %%
City_of_London_Prices = properties_1[properties_1['BOROUGHS_LONDON'] == 'City of London']
City_of_London_Prices.head()
# Out:
#     BOROUGHS_LONDON    CITY_ID      Month  Average Price
# 1    City of London  E09000001 1995-01-01    91448.98487
# 50   City of London  E09000001 1995-02-01    82202.77314
# 99   City of London  E09000001 1995-03-01    79120.70256
# 148  City of London  E09000001 1995-04-01    77101.20804
# 197  City of London  E09000001 1995-05-01    84409.14932

# %%
CoL_LC = City_of_London_Prices.plot.line(x = 'Month', y = 'Average Price', color = 'green', style = '+-')
CoL_LC.set_ylabel('Average Price')
plt.show()

# %%
properties_1['Year'] = properties_1['Month'].apply(lambda t: t.year)
properties_1.head()
# Out:
#       BOROUGHS_LONDON    CITY_ID      Month  Average Price  Year
# 1      City of London  E09000001 1995-01-01    91448.98487  1995
# 2  Barking & Dagenham  E09000002 1995-01-01    50460.22660  1995
# 3              Barnet  E09000003 1995-01-01    93284.51832  1995
# 4              Bexley  E09000004 1995-01-01    64958.09036  1995
# 5               Brent  E09000005 1995-01-01    71306.56698  1995

# %%
prop_2 = properties_1.groupby(by = ['BOROUGHS_LONDON', 'Year']).mean()
prop_2.tail()
# Out:
#                          Average Price
# BOROUGHS_LONDON    Year
# YORKS & THE HUMBER 2016  149015.573233
#                    2017  154819.791333
#                    2018  159936.248338
#                    2019  163424.168033
#                    2020  163092.808067

# %%
Y_H_Prices = prop_2[prop_2['BOROUGHS_LONDON'] == 'YORKS & THE HUMBER']
Y_H_LC = Prop_2.plot.line(x = 'Month', y = 'Average Price', color = 'red', style = '*-')
Y_H_LC.set_ylabel('Average Price')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'BOROUGHS_LONDON'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-2bac4bafd5f2> in <module>
# ----> 1 Y_H_Prices = prop_2[prop_2['BOROUGHS_LONDON'] == 'YORKS & THE HUMBER']
#       2 Y_H_LC = Prop_2.plot.line(x = 'Month', y = 'Average Price', color = 'red', style = '*-')
#       3 Y_H_LC.set_ylabel('Average Price')
#       4 plt.show()
#
# ~\Anaconda3\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\Anaconda3\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'BOROUGHS_LONDON'

# %%
prop_2.sample(15)
# Out:
#                            Average Price
# BOROUGHS_LONDON      Year
# Hammersmith & Fulham 2001  271918.783600
# SOUTH EAST           2001  127928.922817
# Lewisham             2009  211307.586542
#                      2016  402648.691000
# WEST MIDLANDS        2005  145496.493400
# England              2007  190025.643550
# Sutton               2012  238842.177117
# NORTH WEST           2019  164353.319933
# Hillingdon           2017  413586.547825
# Outer London         2010  255640.116908
# Croydon              2001  132509.212908
# WEST MIDLANDS        2009  142189.901533
# Islington            2020  659696.091867
# Hillingdon           2012  260476.430350
# Barking & Dagenham   1998   60285.821083

# %%
prop_2 = prop_2.reset_index()
prop_2.head()
# Out:
#       BOROUGHS_LONDON  Year  Average Price
# 0  Barking & Dagenham  1995   51817.969390
# 1  Barking & Dagenham  1996   51718.192690
# 2  Barking & Dagenham  1997   55974.262309
# 3  Barking & Dagenham  1998   60285.821083
# 4  Barking & Dagenham  1999   65320.934441

# %%
def create_price_ratio(i):
    Year_1998 = float(i['Average Price'][i['Year'] == 1998])
    Year_2018 = float(i['Average Price'][i['Year'] == 2018])
    Price_Ratio = [Year_2018/Year_1998]
    return Price_Ratio

# %%
create_price_ratio(prop_2[prop_2['BOROUGHS_LONDON']=='Barking & Dagenham'])
# Out:
# [4.89661861291754]

# %%
Final = {}

for X in prop_2['BOROUGHS_LONDON'].unique():
    BOROUGH = prop_2[prop_2['BOROUGHS_LONDON'] == X]
    Final[X] = create_price_ratio(BOROUGH)
    
print(Final)
# Out:
# {'Barking & Dagenham': [4.89661861291754], 'Barnet': [4.358195917538044], 'Bexley': [4.248977046127877], 'Brent': [4.8945544971392865], 'Bromley': [4.0947846853338765], 'Camden': [4.935353408884261], 'City of London': [5.301620377587609], 'Croydon': [4.201100280024767], 'EAST MIDLANDS': [3.6327346720877034], 'EAST OF ENGLAND': [4.166900547724156], 'Ealing': [4.311450902121834], 'Enfield': [4.26347158349581], 'England': [3.8104529783974], 'Greenwich': [4.763036347329193], 'Hackney': [6.198285561008662], 'Hammersmith & Fulham': [4.137798101936229], 'Haringey': [5.134624964136042], 'Harrow': [4.0591964329643195], 'Havering': [4.325230371335308], 'Hillingdon': [4.2002730803844575], 'Hounslow': [3.976409106143329], 'Inner London': [5.170857506254785], 'Islington': [4.844048012802298], 'Kensington & Chelsea': [5.082465066092464], 'Kingston upon Thames': [4.270549521484271], 'LONDON': [4.679776249632861], 'Lambeth': [4.957751163514063], 'Lewisham': [5.449221041059685], 'Merton': [4.741273313294604], 'NORTH EAST': [2.828080506434263], 'NORTH WEST': [3.3634156376540654], 'Newham': [5.305390437201879], 'Outer London': [4.418949809440314], 'Redbridge': [4.471182006097364], 'Richmond upon Thames': [4.005161895721457], 'SOUTH EAST': [3.8283877112840563], 'SOUTH WEST': [3.795497124092444], 'Southwark': [5.516485302379376], 'Sutton': [4.118522608573157], 'Tower Hamlets': [4.62670104006116], 'WEST MIDLANDS': [3.3112621931400104], 'Waltham Forest': [5.83475580932281], 'Wandsworth': [4.757709347739269], 'Westminster': [5.353565392605413], 'YORKS & THE HUMBER': [3.356065086028382]}

# %%
Final_Ratios = pd.DataFrame(Final)
Final_Ratios.head()
# Out:
#    Barking & Dagenham    Barnet    Bexley     Brent   Bromley    Camden  \
# 0            4.896619  4.358196  4.248977  4.894554  4.094785  4.935353
#
#    City of London  Croydon  EAST MIDLANDS  EAST OF ENGLAND  ...  SOUTH EAST  \
# 0         5.30162   4.2011       3.632735         4.166901  ...    3.828388
#
#    SOUTH WEST  Southwark    Sutton  Tower Hamlets  WEST MIDLANDS  \
# 0    3.795497   5.516485  4.118523       4.626701       3.311262
#
#    Waltham Forest  Wandsworth  Westminster  YORKS & THE HUMBER
# 0        5.834756    4.757709     5.353565            3.356065
#
# [1 rows x 45 columns]

# %%
Final_Ratios_Tr = Final_Ratios.transpose()
Final_Ratios = Final_Ratios_Tr.reset_index()
Final_Ratios.head()
# Out:
#                 index         0
# 0  Barking & Dagenham  4.896619
# 1              Barnet  4.358196
# 2              Bexley  4.248977
# 3               Brent  4.894554
# 4             Bromley  4.094785

# %%
Final_Ratios.rename(columns = {'index' : 'BOROUGH', 0 : '2018'}, inplace = True)
Final_Ratios.head()
# Out:
#               BOROUGH      2018
# 0  Barking & Dagenham  4.896619
# 1              Barnet  4.358196
# 2              Bexley  4.248977
# 3               Brent  4.894554
# 4             Bromley  4.094785

# %%
Top15_Boroughs = Final_Ratios.sort_values(by = '2018', ascending = False).head(15)
print(Top15_Boroughs)
# Out:
#                  BOROUGH      2018
# 14               Hackney  6.198286
# 41        Waltham Forest  5.834756
# 37             Southwark  5.516485
# 27              Lewisham  5.449221
# 43           Westminster  5.353565
# 31                Newham  5.305390
# 6         City of London  5.301620
# 21          Inner London  5.170858
# 16              Haringey  5.134625
# 23  Kensington & Chelsea  5.082465
# 26               Lambeth  4.957751
# 5                 Camden  4.935353
# 0     Barking & Dagenham  4.896619
# 3                  Brent  4.894554
# 22             Islington  4.844048

# %%
Top15_Chart = Top15_Boroughs[['BOROUGH','2018']].plot(kind = 'bar')

plt.show()

# %%
Top40_Boroughs = Final_Ratios.sort_values(by = '2018', ascending = False).head(40)
print(Top40_Boroughs)
# Out:
#                  BOROUGH      2018
# 14               Hackney  6.198286
# 41        Waltham Forest  5.834756
# 37             Southwark  5.516485
# 27              Lewisham  5.449221
# 43           Westminster  5.353565
# 31                Newham  5.305390
# 6         City of London  5.301620
# 21          Inner London  5.170858
# 16              Haringey  5.134625
# 23  Kensington & Chelsea  5.082465
# 26               Lambeth  4.957751
# 5                 Camden  4.935353
# 0     Barking & Dagenham  4.896619
# 3                  Brent  4.894554
# 22             Islington  4.844048
# 13             Greenwich  4.763036
# 42            Wandsworth  4.757709
# 28                Merton  4.741273
# 25                LONDON  4.679776
# 39         Tower Hamlets  4.626701
# 33             Redbridge  4.471182
# 32          Outer London  4.418950
# 1                 Barnet  4.358196
# 18              Havering  4.325230
# 10                Ealing  4.311451
# 24  Kingston upon Thames  4.270550
# 11               Enfield  4.263472
# 2                 Bexley  4.248977
# 7                Croydon  4.201100
# 19            Hillingdon  4.200273
# 9        EAST OF ENGLAND  4.166901
# 15  Hammersmith & Fulham  4.137798
# 38                Sutton  4.118523
# 4                Bromley  4.094785
# 17                Harrow  4.059196
# 34  Richmond upon Thames  4.005162
# 20              Hounslow  3.976409
# 35            SOUTH EAST  3.828388
# 12               England  3.810453
# 36            SOUTH WEST  3.795497

# %%
Top40_Chart = Top40_Boroughs[['BOROUGH','2018']].plot(kind = 'bar')

plt.show()
